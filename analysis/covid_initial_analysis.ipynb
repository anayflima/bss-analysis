# %% [markdown]
# ## Covid initial data analysis and treatment

# %%
import pandas as pd

# %%
data_path = '../data/covid/original_data/data.csv'

# %%
covid_data = pd.read_csv(data_path)

# %%
covid_data
# Out:
#             date  new_cases_ma  new_deaths_ma  Daily Active Learners  \
# 0     2016-10-06           NaN            NaN                      0
# 1     2016-10-07           NaN            NaN                      0
# 2     2016-10-08           NaN            NaN                      0
# 3     2016-10-09           NaN            NaN                      0
# 4     2016-10-10           NaN            NaN                      0
# ...          ...           ...            ...                    ...
# 2136  2022-08-12       21952.0          214.0                    286
# 2137  2022-08-13       19565.0          188.0                    173
# 2138  2022-08-14       18537.0          180.0                    151
# 2139  2022-08-15       20351.0          199.0                    315
# 2140  2022-08-16       19326.0          176.0                    310
#
#       Monthly Active Learners
# 0                           0
# 1                           0
# 2                           0
# ...

# %%
covid_data = covid_data.drop(['Daily Active Learners', 'Monthly Active Learners'], axis = 1)
covid_data = covid_data.set_index('date')
covid_data
# Out:
#             new_cases_ma  new_deaths_ma
# date
# 2016-10-06           NaN            NaN
# 2016-10-07           NaN            NaN
# 2016-10-08           NaN            NaN
# 2016-10-09           NaN            NaN
# 2016-10-10           NaN            NaN
# ...                  ...            ...
# 2022-08-12       21952.0          214.0
# 2022-08-13       19565.0          188.0
# 2022-08-14       18537.0          180.0
# 2022-08-15       20351.0          199.0
# 2022-08-16       19326.0          176.0
#
# [2141 rows x 2 columns]

# %%
covid_data.plot()

# %%
covid_data.plot(secondary_y='new_deaths_ma')

# %% [markdown]
# First covid data

# %%
covid_data.first_valid_index()
# Out:
# '2020-03-03'

# %%
covid_data['2020-03-03':]
# Out:
#             new_cases_ma  new_deaths_ma
# date
# 2020-03-03           0.0            NaN
# 2020-03-04           0.0            NaN
# 2020-03-05           0.0            NaN
# 2020-03-06           2.0            NaN
# 2020-03-07           2.0            NaN
# ...                  ...            ...
# 2022-08-12       21952.0          214.0
# 2022-08-13       19565.0          188.0
# 2022-08-14       18537.0          180.0
# 2022-08-15       20351.0          199.0
# 2022-08-16       19326.0          176.0
#
# [897 rows x 2 columns]

# %%
covid_data = covid_data['2020-03-06':] # Before this date, data was either null or 0
covid_data
# Out:
#             new_cases_ma  new_deaths_ma
# date
# 2020-03-06           2.0            NaN
# 2020-03-07           2.0            NaN
# 2020-03-08           3.0            NaN
# 2020-03-09           3.0            NaN
# 2020-03-10           4.0            NaN
# ...                  ...            ...
# 2022-08-12       21952.0          214.0
# 2022-08-13       19565.0          188.0
# 2022-08-14       18537.0          180.0
# 2022-08-15       20351.0          199.0
# 2022-08-16       19326.0          176.0
#
# [894 rows x 2 columns]

# %%
covid_data.to_csv('../data/covid/treated_data/data.csv')
