# %%
import pandas as pd

import pandas as pd
import numpy as np
import os
import sys
sys.path.append('./data_analysis')
from modules.CorrelationWithCovid import CorrelationWithCovid
from modules.BestFitting import BestFitting

if 'data_analysis' in os.getcwd():
    data_folder = '../data/'
else:
    data_folder = './data/'

destination_folder_path = data_folder + 'charts/best_fit/'

bf = BestFitting(destination_folder_path)

# %%
cwc = CorrelationWithCovid(data_folder, "week" )

cwc.import_and_prepare_covid_data()
cwc.import_and_prepare_trips_data()
cwc.merge_trips_and_covid_data()

# %%
'''
ax.axvline('2020-03-24', color="black", linestyle="--",  label='Início de medidas restritivas em SP')
ax.axvline('2020-05-27', color="purple", linestyle="--",  label='Plano SP de retomada consciente')
ax.axvline('2020-10-06', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2020-11-30', color="yellow", linestyle="--",  label='Fase Amarela')
ax.axvline('2021-03-15', color="red", linestyle="--",  label='Fase Emergencial')
ax.axvline('2021-08-17', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2021-11-01', color="m", linestyle="--",  label='Fim das restrições')
'''
# Out:
# '\nax.axvline(\'2020-03-24\', color="black", linestyle="--",  label=\'Início de medidas restritivas em SP\')\nax.axvline(\'2020-05-27\', color="purple", linestyle="--",  label=\'Plano SP de retomada consciente\')\nax.axvline(\'2020-10-06\', color="green", linestyle="--",  label=\'Fase Verde\')\nax.axvline(\'2020-11-30\', color="yellow", linestyle="--",  label=\'Fase Amarela\')\nax.axvline(\'2021-03-15\', color="red", linestyle="--",  label=\'Fase Emergencial\')\nax.axvline(\'2021-08-17\', color="green", linestyle="--",  label=\'Fase Verde\')\nax.axvline(\'2021-11-01\', color="m", linestyle="--",  label=\'Fim das restrições\')\n'

# %%
break_dates = {'2020-03-24': "Label1",
               '2020-07-01': "Label2", 
               '2020-10-01': "Label3",
               '2021-04-01': "Label4",
               '2021-11-01': "Label5",
               '2022-01-15': "Label6"}

# %%
len(break_dates)
# Out:
# 6

# %%
list(break_dates.keys())
# Out:
# ['2020-03-24',
#  '2020-07-01',
#  '2020-10-01',
#  '2021-04-01',
#  '2021-11-01',
#  '2022-01-15']

# %%
cwc.trips_and_covid['2020-03': ]
# Out:
#             number_of_trips  tripduration  start_station_id  end_station_id  \
# date
# 2020-03-01          43516.0   1559.053583        124.526747      124.706767
# 2020-03-08          75563.0   1434.849180        115.864802      118.812988
# 2020-03-15          85616.0   1465.032940        120.364044      123.423045
# 2020-03-22          49676.0   1628.817442        127.082998      127.633465
# 2020-03-29          30556.0   1852.619693        130.993651      131.827628
# ...                     ...           ...               ...             ...
# 2022-03-27          41105.0   2935.826968        144.504951      145.776888
# 2022-04-03          38337.0   2957.490034        146.512794      147.836372
# 2022-04-10          44999.0   2941.772700        146.263561      148.256406
# 2022-04-17          38428.0   3050.023484        142.481550      143.819767
# 2022-04-24          43037.0   3220.218928        147.933614      147.555618
#
# ...

# %%
'''
ax.axvline('2020-03-24', color="black", linestyle="--",  label=)
ax.axvline('2020-05-27', color="purple", linestyle="--",  label='Plano SP de retomada consciente')
ax.axvline('2020-10-06', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2020-11-30', color="yellow", linestyle="--",  label='Fase Amarela')
ax.axvline('2021-03-15', color="red", linestyle="--",  label='Fase Emergencial')
ax.axvline('2021-08-17', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2021-11-01', color="m", linestyle="--",  label='Fim das restrições')
'''

trips = cwc.trips_and_covid['2020':]
variable = 'number_of_trips'
break_dates = {'2020-03-24': '',
               '2020-07-01': '', 
               '2020-10-01': '',
               '2021-04-01': '',
               '2021-11-01': '',
               '2022-01-15': ''}



coeffs = bf.find_best_plot_fit(trips, variable, break_dates = break_dates,
                                poly_degree = 1, save = False)

# %%
cwc.trips_and_covid['2020-03']
# Out:
# /tmp/ipykernel_32813/3343673543.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   cwc.trips_and_covid['2020-03']
#             number_of_trips  tripduration  start_station_id  end_station_id  \
# date
# 2020-03-01          43516.0   1559.053583        124.526747      124.706767
# 2020-03-08          75563.0   1434.849180        115.864802      118.812988
# 2020-03-15          85616.0   1465.032940        120.364044      123.423045
# 2020-03-22          49676.0   1628.817442        127.082998      127.633465
# 2020-03-29          30556.0   1852.619693        130.993651      131.827628
#
#                   age       hour  week_day   weekend  holiday  lat_start  \
# date
# 2020-03-01  29.733045  14.515512  3.230099  0.210359  0.23003 -23.580778
# ...

# %%
'''
ax.axvline('2020-03-24', color="black", linestyle="--",  label=)
ax.axvline('2020-05-27', color="purple", linestyle="--",  label='Plano SP de retomada consciente')
ax.axvline('2020-10-06', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2020-11-30', color="yellow", linestyle="--",  label='Fase Amarela')
ax.axvline('2021-03-15', color="red", linestyle="--",  label='Fase Emergencial')
ax.axvline('2021-08-17', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2021-11-01', color="m", linestyle="--",  label='Fim das restrições')
'''

trips = cwc.trips_and_covid['2020-03-22':]
variable = 'number_of_trips'
break_dates = {'2020-03-24': 'Início de medidas restritivas em SP',
               '2020-07-01': 'Fase Verde', 
               '2020-10-01': 'Fase Amarela',
               '2021-04-01': 'Fase Emergencial',
               '2021-11-01': "Fase Verde",
               '2022-01-15': 'Fim das restrições'}
break_dates = {'2020-03-24': 'Início de medidas restritivas em SP',
               '2020-05-27': 'Plano SP de retomada consciente', 
               '2020-10-06': 'Fase Verde', 
               '2020-11-30': 'Fase Amarela',
               '2021-03-15': 'Fase Emergencial',
               '2021-08-17': "Fase Verde",
               '2021-11-01': 'Fim das restrições',
            #    '2022-01-15': 'Quebra identificada'
               }



coeffs = bf.find_best_plot_fit(trips, variable, break_dates = break_dates,
                                poly_degree = 1, save = False, analysis=True)

# %%
'''
ax.axvline('2020-03-24', color="black", linestyle="--",  label=)
ax.axvline('2020-05-27', color="purple", linestyle="--",  label='Plano SP de retomada consciente')
ax.axvline('2020-10-06', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2020-11-30', color="yellow", linestyle="--",  label='Fase Amarela')
ax.axvline('2021-03-15', color="red", linestyle="--",  label='Fase Emergencial')
ax.axvline('2021-08-17', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2021-11-01', color="m", linestyle="--",  label='Fim das restrições')
'''

trips = cwc.trips_and_covid['2020':]
variable = 'number_of_trips'
break_dates = {'2020-03-24': 'Início de medidas restritivas em SP',
               '2020-05-27': 'Plano SP de retomada consciente', 
               '2020-10-06': 'Fase Verde', 
               '2020-11-30': 'Fase Amarela',
               '2021-03-15': 'Fase Emergencial',
               '2021-08-17': "Fase Verde",
               '2021-11-01': 'Fim das restrições'}



coeffs = bf.find_best_plot_fit(trips, variable, break_dates = break_dates,
                                poly_degree = 1, save = False)

# %%
'''
ax.axvline('2020-03-24', color="black", linestyle="--",  label=)
ax.axvline('2020-05-27', color="purple", linestyle="--",  label='Plano SP de retomada consciente')
ax.axvline('2020-10-06', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2020-11-30', color="yellow", linestyle="--",  label='Fase Amarela')
ax.axvline('2021-03-15', color="red", linestyle="--",  label='Fase Emergencial')
ax.axvline('2021-08-17', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2021-11-01', color="m", linestyle="--",  label='Fim das restrições')
'''

trips = cwc.trips_and_covid['2020-03-22':]
# trips["Número de viagens por dia"] = trips['number_of_trips']
variable = 'number_of_trips'
# break_dates = {'2020-03-24': 'Início de medidas restritivas em SP',
#                '2020-07-01': 'Fase Verde', 
#                '2020-10-01': 'Fase Amarela',
#                '2021-04-01': 'Fase Emergencial',
#                '2021-11-01': "Fase Verde",
#                '2022-01-15': 'Fim das restrições'}
break_dates = {
   # '2020-03-06': 'Primeiro caso de COVID-19',
               '2020-03-24': 'Início de medidas restritivas em SP',
            #    '2020-04-01': 'Início de medidas restritivas em SP',
               '2020-05-27': 'Plano SP de retomada consciente', 
               '2020-10-06': 'Fase Verde', 
               '2020-11-30': 'Fase Amarela',
               '2021-01-04': 'Fase Amarela',
               # '2021-02-06': 'Fase Vermelha',
               # '2021-03-01': 'Fase Laranja',
               # '2021-03-06': 'Fase Vermelha',
               # '2021-03-15': 'Fase Emergencial',
               # '2021-04-12': 'Fase Vermelha',
               '2021-08-17': "Fase Verde",
               '2021-11-01': 'Fim das restrições',
               '2022-01-10': 'Festas de final de ano'
               }



coeffs = bf.find_best_plot_fit(trips, variable, break_dates = break_dates,
                                poly_degree = 1, save = True, analysis=True, paint=True,
                                variable_label = 'Número de viagens por dia')

# %%
'''
ax.axvline('2020-03-24', color="black", linestyle="--",  label=)
ax.axvline('2020-05-27', color="purple", linestyle="--",  label='Plano SP de retomada consciente')
ax.axvline('2020-10-06', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2020-11-30', color="yellow", linestyle="--",  label='Fase Amarela')
ax.axvline('2021-03-15', color="red", linestyle="--",  label='Fase Emergencial')
ax.axvline('2021-08-17', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2021-11-01', color="m", linestyle="--",  label='Fim das restrições')
'''

trips = cwc.trips_and_covid['2020-03-22':]
variable = 'number_of_trips'
# break_dates = {'2020-03-24': 'Início de medidas restritivas em SP'}
#                '2020-07-01': 'Fase Verde', 
#                '2020-10-01': 'Fase Amarela',
#                '2021-04-01': 'Fase Emergencial',
#                '2021-11-01': "Fase Verde",
#                '2022-01-15': 'Fim das restrições'}
break_dates = {
               }



coeffs = bf.find_best_plot_fit(trips, variable, break_dates = break_dates,
                                poly_degree = 1, save = True, analysis=True,
                                title="Evolução do número de viagens diárias durante a pandemia do COVID-19",
                                plot_lines=False, variable_label='Número de viagens por dia')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.colors as mcolors

list(mcolors.TABLEAU_COLORS.keys())
# Out:
# ['tab:blue',
#  'tab:orange',
#  'tab:green',
#  'tab:red',
#  'tab:purple',
#  'tab:brown',
#  'tab:pink',
#  'tab:gray',
#  'tab:olive',
#  'tab:cyan']

# %%
trips['2020-03-24':].index
# Out:
# DatetimeIndex(['2020-03-29', '2020-04-05', '2020-04-12', '2020-04-19',
#                '2020-04-26', '2020-05-03', '2020-05-10', '2020-05-17',
#                '2020-05-24', '2020-05-31',
#                ...
#                '2022-02-20', '2022-02-27', '2022-03-06', '2022-03-13',
#                '2022-03-20', '2022-03-27', '2022-04-03', '2022-04-10',
#                '2022-04-17', '2022-04-24'],
#               dtype='datetime64[ns]', name='date', length=109, freq=None)

# %%
coeffs
# Out:
# [array([-17096.1, 239861.8]),
#  array([ -438.04761905, 46148.28571429]),
#  array([  995.6754386 , 11386.52631579]),
#  array([ -2182.48809524, 136632.35714286]),
#  array([ -3930.9, 225391.8]),
#  array([  117.88434751, 23459.70344575]),
#  array([  -896.26363636, 117280.09090909]),
#  array([ -2363.09090909, 270496.03636364]),
#  array([   694.29642857, -41130.2297619 ])]
