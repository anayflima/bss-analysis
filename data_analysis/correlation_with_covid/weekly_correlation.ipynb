# %%
import pandas as pd
import sys
sys.path.append('./data_analysis')
sys.path.append('../../data_analysis')
from modules.CorrelationWithCovid import CorrelationWithCovid

import os

if 'correlation_with_covid' in os.getcwd():
    data_folder = '../../data/'
elif 'data_analysis' in os.getcwd():
    data_folder = '../data/'
else:
    data_folder = './data/'

# %%
cwc = CorrelationWithCovid(data_folder, "week")

cwc.import_and_prepare_covid_data()
cwc.import_and_prepare_trips_data()
cwc.merge_trips_and_covid_data()

# %%
correlation_matrix = cwc.plot_all_correlations()

# %% [markdown]
# ## COVID-19 cases

# %%
correlation_with_variable = cwc.plot_target_variable_correlation(correlation_matrix,
                                                            'new_cases_ma')

# %% [markdown]
# ## COVID-19 deaths

# %%
correlation_with_variable = cwc.plot_target_variable_correlation(correlation_matrix,
                                                            'new_deaths_ma')

# %%
cwc.trips_and_covid['Número de viagens por dia'] = cwc.trips_and_covid['number_of_trips']

# %%
variable = 'Número de viagens por dia'
covid_variable = []
cwc.plot_variable_and_covid_together(variable, covid_variable,save=True)

# %%
variable = 'number_of_trips'
covid_variable = ['new_cases_ma', 'new_deaths_ma']
cwc.plot_variable_and_covid_together(variable, covid_variable, show_all_phases = True)

# %%
variable = 'number_of_trips'
covid_variable = ['new_deaths_ma']
cwc.plot_variable_and_covid_together(variable, covid_variable)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
variable = 'number_of_trips'
covid_variable = []
cwc.plot_variable_and_covid_together(variable, covid_variable,save=True)

# %%
variable = 'number_of_trips'
covid_variable = 'new_deaths_ma'
cwc.plot_variable_and_covid_with_phases(variable, covid_variable)

# %%
variable = 'number_of_trips'
variable_label = 'Número de viagens por dia'
covid_variables = ['new_cases_ma', 'new_deaths_ma']
covid_variables_label = ['Número de casos de COVID-19 por dia', 'Número de mortes por COVID-19 por dia']
cwc.plot_variable_and_covid_together(variable, covid_variables, save = True,
                                     variable_label = variable_label,
                                     covid_variables_label = covid_variables_label,
                                     title = 'Evolução do número de viagens por dia e de variáveis do COVID-19')

# %%
variable = 'number_of_trips'
variable_label = 'Número de viagens por dia'
covid_variables = []
covid_variables_label = []
cwc.plot_variable_and_covid_together(variable, covid_variables, save = True,
                                     variable_label = variable_label,
                                     covid_variables_label = covid_variables_label,
                                     title = 'Evolução do número de viagens por dia')

# %%
cwc.trips_and_covid['tripduration_min'] = cwc.trips_and_covid['tripduration'].apply(lambda x : x//60)

# %%
variable = 'tripduration_min'
variable_label = 'Tempo de duração das viagens (min)'
variable_legend = 'Média diária de duração das viagens'
covid_variables = ['new_cases_ma', 'new_deaths_ma']
covid_variables_label = ['Número de casos de COVID-19 por dia', 'Número de mortes por COVID-19 por dia']
cwc.plot_variable_and_covid_together(variable, covid_variables, save = True,
                                     variable_label = variable_label,
                                     variable_legend = variable_legend,
                                     covid_variables_label = covid_variables_label,
                                     title = 'Evolução de variáveis do COVID-19 e da média diária de duração das viagens')

# %%
variable = 'tripduration_min'
variable_label = 'Tempo de duração das viagens (min)'
variable_legend = 'Média diária de duração das viagens'
covid_variables = []
covid_variables_label = []
cwc.plot_variable_and_covid_together(variable, covid_variables, save = True,
                                     variable_label = variable_label,
                                     variable_legend = variable_legend,
                                     covid_variables_label = covid_variables_label,
                                     title = 'Evolução de variáveis do COVID-19 e da média diária de duração das viagens')

# %%
variable = 'tripduration'
covid_variable = ['new_cases_ma', 'new_deaths_ma']
cwc.plot_variable_and_covid_together(variable, covid_variable, save = True)

# %%
variable = 'tripduration'
covid_variable = ['new_cases_ma', 'new_deaths_ma']
cwc.plot_variable_and_covid_together(variable, covid_variable, show_all_phases=True)

# %%
variable = 'tripduration'
covid_variable = ['new_cases_ma', 'new_deaths_ma']
cwc.plot_variable_and_covid_together(variable, covid_variable, show_all_phases=True)

# %%
variable = 'tripduration'
covid_variable = ['new_cases_ma', 'new_deaths_ma']
cwc.plot_variable_and_covid_together(variable, covid_variable, show_all_phases=False, save=True)

# %%
variable = 'tripduration'
covid_variable = []
cwc.plot_variable_and_covid_together(variable, covid_variable, show_key_pandemic_moments = True, show_all_phases = True)

# %%
variable = 'number_of_trips'
covid_variable = []
cwc.plot_variable_and_covid_together(variable, covid_variable, show_key_pandemic_moments = False)
