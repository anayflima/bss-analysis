# %%
import pandas as pd

# %%
data_folder = '../data/'
trips = pd.read_csv(data_folder + 'trips/loaded_trips/trips_2020.csv')
trips
# Out:
# /tmp/ipykernel_19218/3040597503.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   trips = pd.read_csv(data_folder + 'trips/loaded_trips/trips_2020.csv')
#            Index           trip_id  tripduration  \
# 0              0  8812318BikeSampa          5813
# 1              1  8865693BikeSampa           260
# 2              2  8854630BikeSampa           781
# 3              3  8858198BikeSampa           977
# 4              4  8744681BikeSampa           777
# ...          ...               ...           ...
# 2354962  2354962  7459251BikeSampa          1779
# 2354963  2354963  7459261BikeSampa          2182
# 2354964  2354964  7459264BikeSampa          2181
# 2354965  2354965  7459272BikeSampa          2052
# 2354966  2354966  7459300BikeSampa           434
#
#                    start_station_name            starttime  \
# 0            211 - Capote Valente 145  2020-11-22 10:05:40
# ...

# %%
from modules.DataPreparation import DataPreparation
dp = DataPreparation()

# %%
trips = dp.transform_to_datetime(trips, ['starttime', 'stoptime'])

# %%
trips = dp.transform_to_time_series(trips, 'starttime')

# %%
trips
# Out:
#              Index           trip_id  tripduration  \
# date
# 2020-01-01  860248  5883939BikeSampa           684
# 2020-01-01  860006  5883575BikeSampa          3248
# 2020-01-01  860007  5883614BikeSampa          2717
# 2020-01-01  860008  5883576BikeSampa          2451
# 2020-01-01  860009  5883578BikeSampa          3238
# ...            ...               ...           ...
# 2020-12-31  566816  9076460BikeSampa          1173
# 2020-12-31  568324  9077197BikeSampa           465
# 2020-12-31  619386  9076395BikeSampa          1313
# 2020-12-31  617809  9075578BikeSampa          6810
# 2020-12-31  639676  9076540BikeSampa           934
#
#                            start_station_name           starttime  \
# date
# 2020-01-01  28 - Rua Comendador Miguel Calfat 2020-01-01 13:57:46
# 2020-01-01     131 - Pq. Ibirapuera Portão 06 2020-01-01 12:52:51
# 2020-01-01             322 - Metrô Eucaliptos 2020-01-01 12:52:59
# 2020-01-01                        72 - Queluz 2020-01-01 12:53:09
# ...

# %%
trips_covid = trips.loc['2020-03-06':]
trips_covid
# Out:
#               Index           trip_id  tripduration  \
# date
# 2020-03-06  1212655  6763126BikeSampa           834
# 2020-03-06  1212652  6763123BikeSampa          1079
# 2020-03-06  1212653  6763127BikeSampa          1648
# 2020-03-06  1212651  6763122BikeSampa          2739
# 2020-03-06  1212650  6763124BikeSampa          1692
# ...             ...               ...           ...
# 2020-12-31   566816  9076460BikeSampa          1173
# 2020-12-31   568324  9077197BikeSampa           465
# 2020-12-31   619386  9076395BikeSampa          1313
# 2020-12-31   617809  9075578BikeSampa          6810
# 2020-12-31   639676  9076540BikeSampa           934
#
#                          start_station_name           starttime  \
# date
# 2020-03-06                 24 - Rua Funchal 2020-03-06 17:47:33
# 2020-03-06     19 - Av. Dr. Cardoso de Melo 2020-03-06 17:47:31
# 2020-03-06                     49 - Tapinás 2020-03-06 17:47:32
# 2020-03-06    27 - Rua Min. Jesuíno Cardoso 2020-03-06 17:47:30
# ...

# %%
data_folder = '../data/'
trips_covid.to_csv(data_folder + 'trips/loaded_trips/trips_covid.csv')
