# %%
import pandas as pd
import sys
sys.path.append('./data_analysis')
import os

from modules.DataGrouping import DataGrouping

import time

start = time.time()

if 'data_analysis' in os.getcwd():
    data_folder = '../data/'
else:
    data_folder = './data/'

source_folder_path = data_folder + 'trips/loaded_trips/'
source_analysis_folder_path = data_folder + 'trips/analysis_results/'
# source_folder_path = data_folder + 'trips/test/loaded_trips/'
destination_folder_path = data_folder + 'trips/analysis/'
# destination_folder_path = data_folder + 'trips/test/analysis/'

# trips = pd.read_csv(source_folder_path + 'all_trips.csv')

# %%
trips_after_covid = pd.read_csv(source_folder_path + 'trips_after_covid.csv')

# %%
trips_after_covid
# Out:
#                date  Unnamed: 0    Index      date.1  tripduration  \
# 0        2020-03-06     4494917  4494917  2020-03-06           546
# 1        2020-03-06     4494918  4494918  2020-03-06           834
# 2        2020-03-06     4494919  4494919  2020-03-06           689
# 3        2020-03-06     4494920  4494920  2020-03-06          1079
# 4        2020-03-06     4494921  4494921  2020-03-06          2739
# ...             ...         ...      ...         ...           ...
# 3870688  2022-01-22     8365605  8365605  2022-01-22          1516
# 3870689  2022-01-22     8365606  8365606  2022-01-22          4572
# 3870690  2022-01-22     8365607  8365607  2022-01-22          2113
# 3870691  2022-01-22     8365608  8365608  2022-01-22           916
# 3870692  2022-01-22     8365609  8365609  2022-01-22          1687
#
#                   start_station_name_old  start station id  \
# 0                      172 - Praça da Sé             172.0
# ...

# %%
import math

def to_int(x):
    x = float(x)
    if not math.isnan(x):
        return int(float(x))
    return x

def convert_distance_to_int(trips):
    trips['distance'] = trips['distance'].apply(to_int)
    return trips

def calculate_percentage_of_circular_trips(trips):
    return len(trips[trips['distance'] == 0])/len(trips)

# %%
trips_after_covid = convert_distance_to_int(trips_after_covid)
percentage_after = calculate_percentage_of_circular_trips(trips_after_covid)
percentage_after
# Out:
# 0.1817284398426845

# %%
trips_before_covid = pd.read_csv(source_folder_path + 'trips_before_covid.csv')
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done

# %%
trips_before_covid
# Out:
#                date  Unnamed: 0    Index      date.1  tripduration  \
# 0        2018-01-26           0        0  2018-01-26           114
# 1        2018-01-27           1        1  2018-01-27          3117
# 2        2018-01-27           2        2  2018-01-27           550
# 3        2018-01-27           3        3  2018-01-27          4480
# 4        2018-01-27           4        4  2018-01-27           125
# ...             ...         ...      ...         ...           ...
# 4494912  2020-03-05     4494912  4494912  2020-03-05          1604
# 4494913  2020-03-05     4494913  4494913  2020-03-05          3869
# 4494914  2020-03-05     4494914  4494914  2020-03-05           477
# 4494915  2020-03-05     4494915  4494915  2020-03-05           600
# 4494916  2020-03-05     4494916  4494916  2020-03-05           251
#
#                 start_station_name_old  start station id            starttime  \
# 0                      HQ Test Station               NaN  2018-01-26 15:35:17
# ...

# %%
trips_before_covid = convert_distance_to_int(trips_before_covid)
percentage_before = calculate_percentage_of_circular_trips(trips_before_covid)
percentage_before
# Out:
# 0.10054156728589204

# %%
import pandas as pd
circular_trips_percentage = pd.read_csv(source_analysis_folder_path + 'circular_trips_percentage.csv')

from modules.DataPreparation import DataPreparation
dp = DataPreparation()

circular_trips_percentage = dp.transform_to_datetime(circular_trips_percentage, ['date'])
circular_trips_percentage = dp.transform_to_time_series(circular_trips_percentage, 'date', drop=True)
circular_trips_percentage
# Out:
#             percentage
# date
# 2018-01-01    0.192982
# 2018-02-01    0.137590
# 2018-03-01    0.098437
# 2018-04-01    0.084728
# 2018-05-01    0.079889
# 2018-06-01    0.054168
# 2018-07-01    0.082483
# 2018-08-01    0.068499
# 2018-09-01    0.091474
# 2018-10-01    0.054904
# 2018-11-01    0.079550
# 2018-12-01    0.088438
# 2019-01-01    0.094563
# 2019-02-01    0.074904
# 2019-03-01    0.084684
# 2019-04-01    0.076391
# 2019-05-01    0.079423
# 2019-06-01    0.088146
# 2019-07-01    0.113913
# 2019-08-01    0.119576
# 2019-09-01    0.116565
# 2019-10-01    0.123251
# 2019-11-01    0.136202
# 2019-12-01    0.170479
# 2020-01-01    0.124204
# 2020-02-01    0.126141
# 2020-03-01    0.152678
# 2020-04-01    0.246127
# 2020-05-01    0.228975
# 2020-06-01    0.233343
# 2020-07-01    0.219327
# 2020-08-01    0.218300
# 2020-09-01    0.234387
# 2020-10-01    0.218628
# 2020-11-01    0.196087
# 2020-12-01    0.181355
# 2021-01-01    0.180322
# 2021-02-01    0.154678
# ...

# %%
import matplotlib.pyplot as plt
circular_trips_percentage.plot()
plt.ylim(0)
# Out:
# (0.0, 0.2557254473457975)

# %%
circular_trips_percentage
# Out:
#             percentage
# date
# 2018-01-01    0.192982
# 2018-02-01    0.137590
# 2018-03-01    0.098437
# 2018-04-01    0.084728
# 2018-05-01    0.079889
# 2018-06-01    0.054168
# 2018-07-01    0.082483
# 2018-08-01    0.068499
# 2018-09-01    0.091474
# 2018-10-01    0.054904
# 2018-11-01    0.079550
# 2018-12-01    0.088438
# 2019-01-01    0.094563
# 2019-02-01    0.074904
# 2019-03-01    0.084684
# 2019-04-01    0.076391
# 2019-05-01    0.079423
# 2019-06-01    0.088146
# 2019-07-01    0.113913
# 2019-08-01    0.119576
# 2019-09-01    0.116565
# 2019-10-01    0.123251
# 2019-11-01    0.136202
# 2019-12-01    0.170479
# 2020-01-01    0.124204
# 2020-02-01    0.126141
# 2020-03-01    0.152678
# 2020-04-01    0.246127
# 2020-05-01    0.228975
# 2020-06-01    0.233343
# 2020-07-01    0.219327
# 2020-08-01    0.218300
# 2020-09-01    0.234387
# 2020-10-01    0.218628
# 2020-11-01    0.196087
# 2020-12-01    0.181355
# 2021-01-01    0.180322
# 2021-02-01    0.154678
# ...

# %%
0.137590-0.192982
# Out:
# -0.055392

# %%
circular_trips_percentage.diff()
# Out:
#             percentage
# date
# 2018-01-01         NaN
# 2018-02-01   -0.055393
# 2018-03-01   -0.039153
# 2018-04-01   -0.013709
# 2018-05-01   -0.004839
# 2018-06-01   -0.025721
# 2018-07-01    0.028315
# 2018-08-01   -0.013984
# 2018-09-01    0.022974
# 2018-10-01   -0.036570
# 2018-11-01    0.024646
# 2018-12-01    0.008888
# 2019-01-01    0.006125
# 2019-02-01   -0.019659
# 2019-03-01    0.009780
# 2019-04-01   -0.008292
# 2019-05-01    0.003031
# 2019-06-01    0.008723
# 2019-07-01    0.025767
# 2019-08-01    0.005663
# 2019-09-01   -0.003011
# 2019-10-01    0.006687
# 2019-11-01    0.012950
# 2019-12-01    0.034277
# 2020-01-01   -0.046275
# 2020-02-01    0.001937
# 2020-03-01    0.026537
# 2020-04-01    0.093449
# 2020-05-01   -0.017153
# 2020-06-01    0.004368
# 2020-07-01   -0.014015
# 2020-08-01   -0.001028
# 2020-09-01    0.016087
# 2020-10-01   -0.015759
# 2020-11-01   -0.022541
# 2020-12-01   -0.014732
# 2021-01-01   -0.001033
# 2021-02-01   -0.025644
# ...

# %%
circular_trips_percentage.diff().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
1 - 0.137590/0.192982
# Out:
# 0.28703195116643

# %%
circular_trips_percentage.pct_change()
# Out:
#             percentage
# date
# 2018-01-01         NaN
# 2018-02-01   -0.287034
# 2018-03-01   -0.284562
# 2018-04-01   -0.139268
# 2018-05-01   -0.057108
# 2018-06-01   -0.321959
# 2018-07-01    0.522722
# 2018-08-01   -0.169536
# 2018-09-01    0.335395
# 2018-10-01   -0.399787
# 2018-11-01    0.448899
# 2018-12-01    0.111730
# 2019-01-01    0.069259
# 2019-02-01   -0.207896
# 2019-03-01    0.130566
# 2019-04-01   -0.097923
# 2019-05-01    0.039682
# 2019-06-01    0.109836
# 2019-07-01    0.292318
# 2019-08-01    0.049713
# 2019-09-01   -0.025182
# 2019-10-01    0.057366
# 2019-11-01    0.105072
# 2019-12-01    0.251664
# 2020-01-01   -0.271442
# 2020-02-01    0.015597
# 2020-03-01    0.210378
# 2020-04-01    0.612067
# 2020-05-01   -0.069691
# 2020-06-01    0.019077
# 2020-07-01   -0.060063
# 2020-08-01   -0.004686
# 2020-09-01    0.073694
# 2020-10-01   -0.067235
# 2020-11-01   -0.103104
# 2020-12-01   -0.075128
# 2021-01-01   -0.005696
# 2021-02-01   -0.142215
# ...

# %%
circular_trips_percentage.pct_change().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
circular_trips_percentage_from_2019 = circular_trips_percentage['2019':]
circular_trips_percentage_from_2019
# Out:
#             percentage
# date
# 2019-01-01    0.094563
# 2019-02-01    0.074904
# 2019-03-01    0.084684
# 2019-04-01    0.076391
# 2019-05-01    0.079423
# 2019-06-01    0.088146
# 2019-07-01    0.113913
# 2019-08-01    0.119576
# 2019-09-01    0.116565
# 2019-10-01    0.123251
# 2019-11-01    0.136202
# 2019-12-01    0.170479
# 2020-01-01    0.124204
# 2020-02-01    0.126141
# 2020-03-01    0.152678
# 2020-04-01    0.246127
# 2020-05-01    0.228975
# 2020-06-01    0.233343
# 2020-07-01    0.219327
# 2020-08-01    0.218300
# 2020-09-01    0.234387
# 2020-10-01    0.218628
# 2020-11-01    0.196087
# 2020-12-01    0.181355
# 2021-01-01    0.180322
# 2021-02-01    0.154678
# 2021-03-01    0.182505
# 2021-04-01    0.188068
# 2021-05-01    0.160593
# 2021-06-01    0.156136
# 2021-07-01    0.166750
# 2021-08-01    0.143988
# 2021-09-01    0.162760
# 2021-10-01    0.134811
# 2021-11-01    0.138296
# 2021-12-01    0.132765
# 2022-01-01    0.158176
# 2022-02-01    0.154651
# ...

# %%
circular_trips_percentage_from_2019.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
circular_trips_percentage_from_2019.pct_change().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
import pandas as pd
import os
if 'data_analysis' in os.getcwd():
    data_folder = '../data/'
else:
    data_folder = './data/'

source_folder_path = data_folder + 'trips/analysis/circular_trips/'

circular_trips_month = pd.read_csv(source_folder_path + 'trips_grouped_by_month_mean.csv')

circular_trips_month
# Out:
#           date  number_of_trips  tripduration       hour        age  distance  \
# 0   2018-01-01        13.200000   5432.331424  14.320690        NaN       0.0
# 1   2018-02-01        65.571429   4462.484743  14.032984        NaN       0.0
# 2   2018-03-01        79.032258   5795.936409  13.074659        NaN       0.0
# 3   2018-04-01        91.466667   4290.988858  13.754519        NaN       0.0
# 4   2018-05-01       177.032258   5587.297082  13.764960        NaN       0.0
# 5   2018-06-01       167.033333  16553.659364  13.754764        NaN       0.0
# 6   2018-07-01       298.129032  13640.394219  13.858162        NaN       0.0
# 7   2018-08-01       303.516129  19920.737300  14.054948        NaN       0.0
# 8   2018-09-01       492.433333   7818.638392  13.763922        NaN       0.0
# 9   2018-10-01       292.516129   6435.216744  14.167333        NaN       0.0
# 10  2018-11-01       406.966667   6517.443129  14.269013        NaN       0.0
# ...

# %%
from modules.DataPreparation import DataPreparation
dp = DataPreparation()
circular_trips_month = dp.transform_to_datetime(circular_trips_month, ['date'])
circular_trips_month = dp.transform_to_time_series(circular_trips_month, 'date')

# %%
circular_trips_month.isna().sum()
# Out:
# date                0
# number_of_trips     0
# tripduration        0
# hour                0
# age                24
# distance            0
# week_day            0
# weekend             0
# holiday             0
# dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

def find_best_ploy_fit(trips, variable, poly_degree = 1, period = '', filename = '', save = True):
    plt.clf()
    plt.figure(figsize =(12, 8))
    df = trips.loc['2019':]
    # df = trips.reset_index(drop=True)
    df['range'] = list(range(len(df)))
    x1 = df.loc['2019':'2020-03-24','range']
    y1 = df.loc['2019':'2020-03-24', variable]

    x2 = df.loc['2020-03-24':,'range']
    y2 = df.loc['2020-03-24':, variable]

    # x3 = df.loc['2021-11':,'range']
    # y3 = df.loc['2021-11':, variable]

    index = [i for i in range(len(df))]

    coeffs1 = np.polyfit(x1, y1, poly_degree)
    print()
    poly_eqn = np.poly1d(coeffs1)
    y_hat1 = poly_eqn(x1)

    coeffs2 = np.polyfit(x2, y2, poly_degree)
    poly_eqn = np.poly1d(coeffs2)
    y_hat2 = poly_eqn(x2)

    # coeffs = np.polyfit(x3, y3, poly_degree)
    # poly_eqn = np.poly1d(coeffs)
    # y_hat3 = poly_eqn(x3)

    fig, ax = plt.subplots()
    fig.set_figwidth(20)
    fig.set_figheight(10)

    ax.plot(df.index, df.loc[:, variable], 'ro')
    # y_hat1 = np.pad(y_hat1, (None,len(index) - len(y_hat1)))
    y_hat1 = np.concatenate((y_hat1,[None]*(len(df.index) - len(y_hat1))))
    y_hat2 = np.concatenate(([None]*(len(df.index) - len(y_hat2)), y_hat2))
    # y_hat2 = np.concatenate(([None]*(len(x1)), y_hat2, [None]*(len(x3))))
    # y_hat3 = np.concatenate(([None]*(len(df.index) - len(y_hat3)), y_hat3))
    plt.plot(df.index,y_hat1)
    plt.plot(df.index,y_hat2)
    # plt.plot(df.index,y_hat3)
    plt.ylim(bottom=0)
    plt.ylim(top=df[variable].max()*1.05)
    # plt.ylim(top=12500)
    # ax.axvline(pd.to_datetime('2020-03-06'), color="black", linestyle="--",  label='Início da quarentena')
    ax.axvline(pd.to_datetime('2020-03-24'), color="black", linestyle="--",  label='Início da quarentena')

    title = 'Monthly variation of variable {variable}'.format(variable = variable)
    for label in (ax.get_xticklabels() + ax.get_yticklabels()):
        label.set_fontsize(16)
    plt.title(title, size=22, pad = 10)
    if save:
        filename = variable + '_' + filename + '_' + str(poly_degree) + '.png'
        plt.savefig(destination_folder_path + filename) 
    return coeffs1,coeffs2

# %%
circular_trips_drop =  circular_trips_month[circular_trips_month['tripduration'] < 10000]

# %%
variable = 'tripduration'
coeffs = find_best_ploy_fit(circular_trips_drop, variable, 1, 'Before Covid for ', 'before', False)
# Out:
# /tmp/ipykernel_4498/1435885481.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['range'] = list(range(len(df)))

# %%
coeffs
# Out:
# (array([-256.88448254, 5069.75909469]), array([ 187.15055082, -535.93124521]))

# %%
variable = 'tripduration'
coeffs = find_best_ploy_fit(circular_trips_month, variable, 1, 'Before Covid for ', 'before', False)
# Out:
# /tmp/ipykernel_4498/1435885481.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['range'] = list(range(len(df)))

# %%
circular_trips_month['tripduration'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
import pandas as pd
import os
if 'data_analysis' in os.getcwd():
    data_folder = '../data/'
else:
    data_folder = './data/'

source_folder_path = data_folder + 'trips/analysis_results/'

circular_trips = pd.read_csv(source_folder_path + 'circular_trips.csv')

from modules.DataPreparation import DataPreparation
dp = DataPreparation()
circular_trips = dp.transform_to_datetime(circular_trips, ['date'])
circular_trips = dp.transform_to_time_series(circular_trips, 'date')
circular_trips
# Out:
# /tmp/ipykernel_5142/420869994.py:10: DtypeWarning: Columns (13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   circular_trips = pd.read_csv(source_folder_path + 'circular_trips.csv')
#                  date  tripduration                start_station_name_old  \
# date
# 2018-01-27 2018-01-27           550                  10 - Rua Campo Verde
# 2018-01-29 2018-01-29         37552  16 - Esporte Clube Pinheiros Boliche
# 2018-01-29 2018-01-29          2758             7 - Praça Joaquim Roberto
# 2018-01-29 2018-01-29          1889                   1 - Largo da Batata
# 2018-01-29 2018-01-29           315             7 - Praça Joaquim Roberto
# ...               ...           ...                                   ...
# 2022-04-30 2022-04-30         27898        267 - CPTM Villa Lobos Jaguaré
# 2022-04-30 2022-04-30          2112                86 - Shopping Center 3
# 2022-04-30 2022-04-30         12284                          121 - Insper
# ...

# %%
len(circular_trips[circular_trips['weekend']])/len(circular_trips)
# Out:
# 0.3807802792600657

# %%
circular_trips_before = circular_trips[:'2020-03-05']
circular_trips_before
# Out:
#                  date  tripduration                start_station_name_old  \
# date
# 2018-01-27 2018-01-27           550                  10 - Rua Campo Verde
# 2018-01-29 2018-01-29         37552  16 - Esporte Clube Pinheiros Boliche
# 2018-01-29 2018-01-29          2758             7 - Praça Joaquim Roberto
# 2018-01-29 2018-01-29          1889                   1 - Largo da Batata
# 2018-01-29 2018-01-29           315             7 - Praça Joaquim Roberto
# ...               ...           ...                                   ...
# 2020-03-05 2020-03-05          2459         115 - Praça Procopio Ferreira
# 2020-03-05 2020-03-05          2581                  18 - Itaú Faria Lima
# 2020-03-05 2020-03-05            91                  175 - R. Luis Coelho
# 2020-03-05 2020-03-05          3473             79 - R. José Maria Lisboa
# 2020-03-05 2020-03-05          2326            135 - Ibirapuera Portão 10
#
#             start station id            starttime  \
# date
# ...

# %%
len(circular_trips_before[circular_trips_before['weekend']])/len(circular_trips_before)
# Out:
# 0.3804171642241895

# %%
circular_trips_after = circular_trips[:'2020-03-05']
circular_trips_after
# Out:
#                  date  tripduration                start_station_name_old  \
# date
# 2018-01-27 2018-01-27           550                  10 - Rua Campo Verde
# 2018-01-29 2018-01-29         37552  16 - Esporte Clube Pinheiros Boliche
# 2018-01-29 2018-01-29          2758             7 - Praça Joaquim Roberto
# 2018-01-29 2018-01-29          1889                   1 - Largo da Batata
# 2018-01-29 2018-01-29           315             7 - Praça Joaquim Roberto
# ...               ...           ...                                   ...
# 2020-03-05 2020-03-05          2459         115 - Praça Procopio Ferreira
# 2020-03-05 2020-03-05          2581                  18 - Itaú Faria Lima
# 2020-03-05 2020-03-05            91                  175 - R. Luis Coelho
# 2020-03-05 2020-03-05          3473             79 - R. José Maria Lisboa
# 2020-03-05 2020-03-05          2326            135 - Ibirapuera Portão 10
#
#             start station id            starttime  \
# date
# ...

# %%
len(circular_trips_after[circular_trips_after['weekend']])/len(circular_trips_after)
# Out:
# 0.38140536282488724

# %%
circular_trips_before = circular_trips['2020-03-06':]
circular_trips_before
# Out:
#                  date  tripduration          start_station_name_old  \
# date
# 2020-03-06 2020-03-06          1630   36 - E.E. Aristides de Castro
# 2020-03-06 2020-03-06          1112          322 - Metrô Eucaliptos
# 2020-03-06 2020-03-06          1099               319 - Metrô Moema
# 2020-03-06 2020-03-06           285          322 - Metrô Eucaliptos
# 2020-03-06 2020-03-06          2111   51 - Praça Luiz Delben Junior
# ...               ...           ...                             ...
# 2022-04-30 2022-04-30         27898  267 - CPTM Villa Lobos Jaguaré
# 2022-04-30 2022-04-30          2112          86 - Shopping Center 3
# 2022-04-30 2022-04-30         12284                    121 - Insper
# 2022-04-30 2022-04-30         17209                   40 - Brasília
# 2022-04-30 2022-04-30          2144          85 - Praça do Ciclista
#
#             start station id            starttime  \
# date
# 2020-03-06              36.0  2020-03-06 17:47:59
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

from  matplotlib.ticker import FuncFormatter
bins = np.concatenate((list(range(0,14401,1200)), [28800, 57600]))
ax = sns.histplot(data=circular_trips['tripduration'], bins = bins, stat='percent')
for i in ax.containers:
    ax.bar_label(i,fmt='%.1f')
ax.set_xticks(range(0,57601,4800))
figure(figsize=(12, 6), dpi=80)
ax.xaxis.set_major_formatter(FuncFormatter(lambda x, _: x//120))
ax.set(xlabel='Trip duration (min)', ylabel='Percent of trips (%)')
ax.set(title='Trip duration distribution in circular trips')
# plt.savefig(data_folder + 'charts/histograms/trip_duration_after_covid.png')
# Out:
# [Text(0.5, 1.0, 'Trip duration distribution in circular trips')]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

from  matplotlib.ticker import FuncFormatter
# bins = np.concatenate((list(range(0,14401,1200))))
bins = list(range(0,14401,1200))
ax = sns.histplot(data=circular_trips['tripduration'], bins = bins, stat='percent')
for i in ax.containers:
    ax.bar_label(i,fmt='%.1f')
ax.set_xticks(range(0,14401,1200))
# figure(figsize=(12, 6))
ax.xaxis.set_major_formatter(FuncFormatter(lambda x, _: x//60))
ax.set(xlabel='Trip duration (min)', ylabel='Percent of trips (%)')
ax.set(title='Trip duration distribution in circular trips')
# plt.figure(figsize=(20,6))
plt.savefig(data_folder + 'charts/histograms/circular_trips_tripduration.png')

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from  matplotlib.ticker import FuncFormatter
# bins = np.concatenate((list(range(0,14401,1200))))
# fig, ax = plt.subplots()
bins = list(range(0,281*60,1200))
ax = sns.histplot(data=circular_trips['2020-03-06':]['tripduration'], bins = bins, stat='percent')
sns.set(rc={'figure.figsize':(10,8)})
for i in ax.containers:
    ax.bar_label(i,fmt='%.1f')
ax.set_ylim(bottom = 0, top = 33)
ax.set_xticks(range(0,281*60,1200))
# figure(figsize=(12, 6))
ax.xaxis.set_major_formatter(FuncFormatter(lambda x, _: x//60))
ax.set(xlabel='Trip duration (min)', ylabel='Percent of trips (%)')
ax.set(title='Trip duration distribution in circular trips after covid')
# plt.figure(figsize=(20,6))
plt.savefig(data_folder + 'charts/histograms/circular_trips_tripduration_after_covid.png')

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# from matplotlib.pyplot import figure

from  matplotlib.ticker import FuncFormatter
# bins = np.concatenate((list(range(0,14401,1200))))
# fig, ax = plt.subplots()
bins = list(range(0,281*60,1200))
ax = sns.histplot(data=circular_trips[:'2020-03-05']['tripduration'], bins = bins, stat='percent')
# sns.set(rc={'figure.figsize':(20,8)})
for i in ax.containers:
    ax.bar_label(i,fmt='%.1f')
ax.set_ylim(bottom = 0, top = 33)
ax.set_xticks(range(0,281*60,1200))
# figure(figsize=(12, 6))
ax.xaxis.set_major_formatter(FuncFormatter(lambda x, _: x//60))
ax.set(xlabel='Trip duration (min)', ylabel='Percent of trips (%)')
ax.set(title='Trip duration distribution in circular trips before covid')
# plt.figure(figsize=(20,6))
plt.savefig(data_folder + 'charts/histograms/circular_trips_tripduration_before_covid.png')

# %%
len(circular_trips[circular_trips['tripduration'] > 14400])
# Out:
# 30296

# %%
len(circular_trips[circular_trips['tripduration'] > 14400*2])
# Out:
# 10498

# %%
len(circular_trips)
# Out:
# 1229893

# %%
len(circular_trips[circular_trips['tripduration'] > 14400])/len(circular_trips)
# Out:
# 0.024633037182909406

# %%
circular_trips['tripduration']
# Out:
# date
# 2018-01-27      550
# 2018-01-29    37552
# 2018-01-29     2758
# 2018-01-29     1889
# 2018-01-29      315
#               ...
# 2022-04-30    27898
# 2022-04-30     2112
# 2022-04-30    12284
# 2022-04-30    17209
# 2022-04-30     2144
# Name: tripduration, Length: 1229893, dtype: int64

# %%
circular_trips_weekend = circular_trips[circular_trips['weekend']]
circular_trips_weekday = circular_trips[circular_trips['weekend'] == False]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

from  matplotlib.ticker import FuncFormatter

def plot_histogram(trips, period = 'all', day = ''):
    bins = np.concatenate((list(range(0,121*60,1200)), [280*60]))
    if period == 'before':
        trips = trips[:'2020-03-05']
    elif period == 'after':
        trips = trips['2020-03-06':]
    ax = sns.histplot(data=trips['tripduration'], bins = bins, stat='percent')
    sns.set(rc={'figure.figsize':(20,8)})
    for i in ax.containers:
        ax.bar_label(i,fmt='%.1f')
    ax.set_ylim(bottom = 0, top = 40)
    ax.set_xticks(range(0,281*60,1200))
    # figure(figsize=(12, 6))
    ax.xaxis.set_major_formatter(FuncFormatter(lambda x, _: x//60))
    ax.set(xlabel='Trip duration (min)', ylabel='Percent of trips (%)')
    if period != 'all' and day != '':
        ax.set(title='Trip duration distribution in circular trips ' + period + ' covid' + ' for ' + day)
    else:
        ax.set(title='Trip duration distribution in circular trips')
    # plt.figure(figsize=(20,6))
    plt.savefig(data_folder + 'charts/histograms/circular_trips_tripduration_'+ day+'_' +period+'_covid.png')

# %%
plot_histogram(circular_trips_weekend)

# %%
plot_histogram(circular_trips_weekday)

# %%
plot_histogram(circular_trips_weekday, 'before', 'weekday')

# %%
plot_histogram(circular_trips_weekend, 'before', 'weekend')

# %%
plot_histogram(circular_trips_weekday, 'after', 'weekday')

# %%
plot_histogram(circular_trips_weekend, 'after', 'weekend')
