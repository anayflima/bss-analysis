# %%
import pandas as pd

import pandas as pd
import numpy as np
import os
import sys
sys.path.append('./data_analysis')
from modules.CorrelationWithCovid import CorrelationWithCovid
from modules.BestFitting import BestFitting

if 'data_analysis' in os.getcwd():
    data_folder = '../data/'
else:
    data_folder = './data/'

destination_folder_path = data_folder + 'charts/best_fit/'

bf = BestFitting(destination_folder_path)

# %% [markdown]
# ## Trips grouped by month

# %%
cwc = CorrelationWithCovid(data_folder, "week")

cwc.import_and_prepare_covid_data()
cwc.import_and_prepare_trips_data()
cwc.merge_trips_and_covid_data()

# %%
variable = 'number_of_trips'
break_dates = {
                '2020-03-24' : 'Início do Lockdown em SP'}

coeffs = bf.find_best_plot_fit(cwc.trips_and_covid, variable, break_dates = break_dates,
                                        poly_degree = 1, save = True)

# %%
coeffs
# Out:
# [array([ 583.66783408, 9204.70306574]),
#  array([-4.22906403e+01,  4.28497142e+04])]

# %%
variable = 'number_of_trips'
break_dates = { 
                '2018-02-01': 'Início dos dados',
                '2020-03-24' : 'Início do Lockdown em SP'}

coeffs = bf.find_best_plot_fit(cwc.trips_and_covid, variable, break_dates = break_dates,
                                        poly_degree = 1, save = False, analysis=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       1 variable = 'number_of_trips'
#       2 break_dates = {
#       3                 '2018-02-01': 'Início dos dados',
#       4                 '2020-03-24' : 'Início do Lockdown em SP'}
# ----> 6 coeffs = bf.find_best_plot_fit(cwc.trips_and_covid, variable, break_dates = break_dates,
#       7                                         poly_degree = 1, save = False, analysis=False)
#
# File ~/Documents/bss-analysis/data_analysis/modules/BestFitting.py:64, in BestFitting.find_best_plot_fit(self, trips, variable, break_dates, poly_degree, save, filename, analysis)
#      62 xs.append(x)
#      63 ys.append(y)
# ---> 64 coeff = np.polyfit(x, y, poly_degree)
#      65 poly_eqn = np.poly1d(coeff)
#      66 y_hat = poly_eqn(x)
#
# File <__array_function__ internals>:180, in polyfit(*args, **kwargs)
#
# File ~/Documents/bss-analysis/virtualenv/lib/python3.8/site-packages/numpy/lib/polynomial.py:638, in polyfit(x, y, deg, rcond, full, w, cov)
#     636     raise TypeError("expected 1D vector for x")
#     637 if x.size == 0:
# --> 638     raise TypeError("expected non-empty vector for x")
#     639 if y.ndim < 1 or y.ndim > 2:
#     640     raise TypeError("expected 1D or 2D array for y")
#
# TypeError: expected non-empty vector for x

# %%
variable = 'tripduration'
break_dates = { '2020-03-24' : 'Início do Lockdown em SP'}

coeffs = bf.find_best_plot_fit(cwc.trips_and_covid, variable, break_dates = break_dates,
                                        poly_degree = 1, save = False)

# %%
variable = 'tripduration'
break_dates = ['2020-03-24', '2020-08-01','2021-04-01']

coeffs = bf.find_best_plot_fit(cwc.trips_and_covid, variable, break_dates = break_dates,
                                        poly_degree = 1, save = False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       1 variable = 'tripduration'
#       2 break_dates = ['2020-03-24', '2020-08-01','2021-04-01']
# ----> 4 coeffs = bf.find_best_plot_fit(cwc.trips_and_covid, variable, break_dates = break_dates,
#       5                                         poly_degree = 1, save = False)
#
# File ~/Documents/bss-analysis/data_analysis/modules/BestFitting.py:41, in BestFitting.find_best_plot_fit(self, trips, variable, break_dates, poly_degree, save, filename, analysis)
#      37 coeffs = []
#      38 y_hats = []
# ---> 41 keys = list(break_dates.keys())
#      42 if len(break_dates) > 0:
#      43     for i in range(1, len(break_dates) + 1):
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
variable = 'number_of_trips'
# break_dates = ['2020-03-24', '2020-08-01','2021-04-01']

coeffs = bf.find_best_plot_fit(cwc.trips_and_covid, variable,
                                        poly_degree = 1, save = False)

# %% [markdown]
# ## Trips group by week

# %%
cwc = CorrelationWithCovid(data_folder, "week")

cwc.import_and_prepare_covid_data()
cwc.import_and_prepare_trips_data()
cwc.merge_trips_and_covid_data()

# %%
variable = 'tripduration'
break_dates = {'2020-03-24':'', '2020-09-15':'','2021-05-01':''}

coeffs = bf.find_best_plot_fit(cwc.trips_and_covid, variable, break_dates = break_dates,
                                        poly_degree = 1, save = True)

# %%
coeffs
# Out:
# [array([  -1.9192082 , 1604.72123039]),
#  array([  -2.25302399, 2111.33438722]),
#  array([   58.30899931, -6056.04021192]),
#  array([ -14.29383707, 6247.2042053 ])]

# %%
cwc = CorrelationWithCovid(data_folder, "day")

cwc.import_and_prepare_covid_data()
cwc.import_and_prepare_trips_data()
cwc.merge_trips_and_covid_data()

# %%
variable = 'tripduration'
break_dates = {'2020-03-24':'', '2020-08-01':'','2021-04-01':''}

coeffs = bf.find_best_plot_fit(cwc.trips_and_covid, variable, break_dates = break_dates,
                                        poly_degree = 1, save = True)

# %%
coeffs
# Out:
# [array([-5.74106458e-01,  1.89446045e+03]),
#  array([-5.44338502e-01,  2.28335036e+03]),
#  array([    8.42476862, -6176.92754606]),
#  array([-1.91279609e+00,  6.08437450e+03])]

# %%
variable = 'number_of_trips'
# break_dates = ['2020-03-24', '2020-08-01','2021-04-01']

coeffs = bf.find_best_plot_fit(cwc.trips_and_covid, variable,
                                poly_degree = 1, save = False)

# %%
'''
ax.axvline('2020-03-24', color="black", linestyle="--",  label='Início do lockdown em SP')
ax.axvline('2020-05-27', color="purple", linestyle="--",  label='Plano SP de retomada consciente')
ax.axvline('2020-10-06', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2020-11-30', color="yellow", linestyle="--",  label='Fase Amarela')
ax.axvline('2021-03-15', color="red", linestyle="--",  label='Fase Emergencial')
ax.axvline('2021-08-17', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2021-11-01', color="m", linestyle="--",  label='Fim das restrições')
'''
# Out:
# '\nax.axvline(\'2020-03-24\', color="black", linestyle="--",  label=\'Início do lockdown em SP\')\nax.axvline(\'2020-05-27\', color="purple", linestyle="--",  label=\'Plano SP de retomada consciente\')\nax.axvline(\'2020-10-06\', color="green", linestyle="--",  label=\'Fase Verde\')\nax.axvline(\'2020-11-30\', color="yellow", linestyle="--",  label=\'Fase Amarela\')\nax.axvline(\'2021-03-15\', color="red", linestyle="--",  label=\'Fase Emergencial\')\nax.axvline(\'2021-08-17\', color="green", linestyle="--",  label=\'Fase Verde\')\nax.axvline(\'2021-11-01\', color="m", linestyle="--",  label=\'Fim das restrições\')\n'

# %%
trips = cwc.trips_and_covid['2020':]
variable = 'number_of_trips'
break_dates = ['2020-03-24', '2020-05-27', '2020-10-06','2020-11-30',
               '2021-03-15', '2021-08-17', '2021-11-01']

coeffs = bf.find_best_plot_fit(trips, variable,break_dates = break_dates,
                                poly_degree = 1, save = False)

# %%
trips = cwc.trips_and_covid['2020':]
variable = 'number_of_trips'
break_dates = ['2020-03-24', '2020-07-01', '2020-10-01','2021-04-01',
               '2021-11-01', '2022-01-15']

coeffs = bf.find_best_plot_fit(trips, variable,break_dates = break_dates,
                                poly_degree = 1, save = False)
