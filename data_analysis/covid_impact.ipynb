# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_folder = '../data/'
trips = pd.read_csv(data_folder + 'trips/analysis/trips_grouped_by_day.csv')

from modules.DataPreparation import DataPreparation
dp = DataPreparation()
trips = dp.transform_to_datetime(trips, ['date'])
trips = dp.transform_to_time_series(trips, 'date', drop = True)
trips
# Out:
#             number_of_trips  tripduration       hour        age     distance  \
# date
# 2018-01-26                1    114.000000  15.000000        NaN          NaN
# 2018-01-27                8   2263.250000  14.250000        NaN   787.000000
# 2018-01-28               12   7208.666667  14.833333        NaN  1135.300000
# 2018-01-29                8   5821.875000  15.500000        NaN   195.500000
# 2018-01-30               69   3208.202899  16.144928        NaN  1248.483333
# ...                     ...           ...        ...        ...          ...
# 2022-04-26             7014   2645.781152  13.606929  31.908143  2433.724705
# 2022-04-27             7322   2684.503688  13.571019  31.709845  2404.509035
# 2022-04-28             7192   2778.109844  13.484705  31.698189  2390.592556
# 2022-04-29             5707   3267.835290  13.171894  31.182616  2308.744780
# 2022-04-30             3917   3817.494256  13.952770  31.613811  2121.760717
#
#             week_day  weekend  holiday
# date
# 2018-01-26       4.0      0.0      0.0
# 2018-01-27       5.0      1.0      0.0
# 2018-01-28       6.0      1.0      0.0
# 2018-01-29       0.0      0.0      0.0
# 2018-01-30       1.0      0.0      0.0
# ...              ...      ...      ...
# 2022-04-26       1.0      0.0      0.0
# 2022-04-27       2.0      0.0      0.0
# 2022-04-28       3.0      0.0      0.0
# 2022-04-29       4.0      0.0      0.0
# 2022-04-30       5.0      1.0      0.0
#
# [1556 rows x 8 columns]

# %%
trips['age'].first_valid_index()
trips['age'].isna().sum()
# Out:
# 705

# %% [markdown]
# #### Let's plot some variables separately to see the evolution
#
# - [x] Number of trips
# - [x] Average of trip_duration
# - [x] Age of people
# - [ ] Trip distance

# %%
trips['number_of_trips'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
trips['2020':]['number_of_trips'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
trips['tripduration'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
trips['age'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# !pip3 install pandas_bokeh
# Out:
# Requirement already satisfied: pandas_bokeh in /home/ana/.local/lib/python3.8/site-packages (0.5.5)
# Requirement already satisfied: pandas>=0.22.0 in /home/ana/.local/lib/python3.8/site-packages (from pandas_bokeh) (1.4.4)
# Requirement already satisfied: bokeh>=2.0 in /home/ana/.local/lib/python3.8/site-packages (from pandas_bokeh) (3.0.0)
# Requirement already satisfied: pytz>=2020.1 in /home/ana/.local/lib/python3.8/site-packages (from pandas>=0.22.0->pandas_bokeh) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ana/.local/lib/python3.8/site-packages (from pandas>=0.22.0->pandas_bokeh) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in /home/ana/.local/lib/python3.8/site-packages (from pandas>=0.22.0->pandas_bokeh) (1.23.3)
# Requirement already satisfied: Jinja2>=2.9 in /home/ana/.local/lib/python3.8/site-packages (from bokeh>=2.0->pandas_bokeh) (3.1.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /home/ana/.local/lib/python3.8/site-packages (from bokeh>=2.0->pandas_bokeh) (2022.9.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/lib/python3/dist-packages (from bokeh>=2.0->pandas_bokeh) (5.3.1)
# Requirement already satisfied: tornado>=5.1 in /home/ana/.local/lib/python3.8/site-packages (from bokeh>=2.0->pandas_bokeh) (6.2)
# Requirement already satisfied: packaging>=16.8 in /home/ana/.local/lib/python3.8/site-packages (from bokeh>=2.0->pandas_bokeh) (21.3)
# Requirement already satisfied: contourpy>=1 in /home/ana/.local/lib/python3.8/site-packages (from bokeh>=2.0->pandas_bokeh) (1.0.6)
# Requirement already satisfied: pillow>=7.1.0 in /home/ana/.local/lib/python3.8/site-packages (from bokeh>=2.0->pandas_bokeh) (9.3.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in /home/ana/.local/lib/python3.8/site-packages (from bokeh>=2.0->pandas_bokeh) (4.3.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas>=0.22.0->pandas_bokeh) (1.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ana/.local/lib/python3.8/site-packages (from Jinja2>=2.9->bokeh>=2.0->pandas_bokeh) (2.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ana/.local/lib/python3.8/site-packages (from packaging>=16.8->bokeh>=2.0->pandas_bokeh) (3.0.9)

# %% [markdown]
# ## Month

# %%
data_folder = '../data/'
trips_month = pd.read_csv(data_folder + 'trips/analysis/trips_grouped_by_month_mean.csv')

from modules.DataPreparation import DataPreparation
dp = DataPreparation()
trips_month = dp.transform_to_datetime(trips_month, ['date'])
trips_month = dp.transform_to_time_series(trips_month, 'date', drop = True)
trips_month.head()
# Out:
#             number_of_trips  tripduration       hour  age     distance  \
# date
# 2018-01-01        57.000000   3585.398001  15.247060  NaN  1102.535977
# 2018-02-01       476.571429   2237.209127  13.638006  NaN  1925.366525
# 2018-03-01       802.870968   2569.867173  13.008217  NaN  2126.458294
# 2018-04-01      1079.533333   2024.101274  13.361577  NaN  2217.028254
# 2018-05-01      2215.967742   1975.162249  13.470241  NaN  2465.867782
#
#             week_day   weekend   holiday
# date
# 2018-01-01  3.000000  0.333333  0.000000
# 2018-02-01  3.000000  0.285714  0.071429
# 2018-03-01  3.096774  0.290323  0.032258
# 2018-04-01  3.000000  0.300000  0.066667
# 2018-05-01  2.903226  0.258065  0.064516

# %%
trips_month['number_of_trips'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
trips_month['2020':]['number_of_trips'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
trips_month['tripduration'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
trips_month['age'].plot()
plt.ylim(bottom=0)
plt.title('Age average variation')
# Out:
# Text(0.5, 1.0, 'Age average variation')

# %%
trips_month['distance'].plot()
plt.ylim(bottom=0)
# Out:
# (0.0, 2705.486781437204)

# %%
trips_month['weekend'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
trips_month['week_day'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
trips_month['week_day']
# Out:
# date
# 2018-01-01    3.000000
# 2018-02-01    3.000000
# 2018-03-01    3.096774
# 2018-04-01    3.000000
# 2018-05-01    2.903226
# 2018-06-01    3.100000
# 2018-07-01    2.935484
# 2018-08-01    3.000000
# 2018-09-01    3.166667
# 2018-10-01    2.806452
# 2018-11-01    3.033333
# 2018-12-01    3.064516
# 2019-01-01    2.903226
# 2019-02-01    3.000000
# 2019-03-01    3.193548
# 2019-04-01    2.833333
# 2019-05-01    3.000000
# 2019-06-01    3.166667
# 2019-07-01    2.880000
# 2019-08-01    3.080000
# 2019-09-01    3.083333
# 2019-10-01    2.760000
# 2019-11-01    3.125000
# 2019-12-01    3.000000
# 2020-01-01    3.000000
# 2020-02-01    3.068966
# 2020-03-01    2.935484
# 2020-04-01    2.966667
# 2020-05-01    3.193548
# 2020-06-01    2.833333
# 2020-07-01    3.000000
# 2020-08-01    3.064516
# 2020-09-01    2.900000
# 2020-10-01    3.096774
# 2020-11-01    3.000000
# 2020-12-01    2.903226
# 2021-01-01    3.193548
# 2021-02-01    3.000000
# 2021-03-01    2.806452
# 2021-04-01    3.033333
# 2021-05-01    3.064516
# 2021-06-01    2.900000
# 2021-07-01    3.096774
# 2021-08-01    2.935484
# 2021-09-01    2.966667
# 2021-10-01    3.193548
# 2021-11-01    2.833333
# 2021-12-01    3.000000
# 2022-01-01    3.064516
# 2022-02-01    3.000000
# 2022-03-01    2.903226
# 2022-04-01    3.100000
# Name: week_day, dtype: float64

# %%
trips_month['hour'].plot()
plt.ylim(bottom=0)
# Out:
# (0.0, 15.359002033283321)
