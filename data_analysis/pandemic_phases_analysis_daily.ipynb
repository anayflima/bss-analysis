# %%
import pandas as pd

import pandas as pd
import numpy as np
import os
import sys
sys.path.append('./data_analysis')
from modules.CorrelationWithCovid import CorrelationWithCovid
from modules.BestFitting import BestFitting

if 'data_analysis' in os.getcwd():
    data_folder = '../data/'
else:
    data_folder = './data/'

destination_folder_path = data_folder + 'charts/best_fit/'

bf = BestFitting(destination_folder_path)

# %%
cwc = CorrelationWithCovid(data_folder, "day" )

cwc.import_and_prepare_covid_data()
cwc.import_and_prepare_trips_data()
cwc.merge_trips_and_covid_data()

# %%
'''
ax.axvline('2020-03-24', color="black", linestyle="--",  label='Início do lockdown em SP')
ax.axvline('2020-05-27', color="purple", linestyle="--",  label='Plano SP de retomada consciente')
ax.axvline('2020-10-06', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2020-11-30', color="yellow", linestyle="--",  label='Fase Amarela')
ax.axvline('2021-03-15', color="red", linestyle="--",  label='Fase Emergencial')
ax.axvline('2021-08-17', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2021-11-01', color="m", linestyle="--",  label='Fim das restrições')
'''
# Out:
# '\nax.axvline(\'2020-03-24\', color="black", linestyle="--",  label=\'Início do lockdown em SP\')\nax.axvline(\'2020-05-27\', color="purple", linestyle="--",  label=\'Plano SP de retomada consciente\')\nax.axvline(\'2020-10-06\', color="green", linestyle="--",  label=\'Fase Verde\')\nax.axvline(\'2020-11-30\', color="yellow", linestyle="--",  label=\'Fase Amarela\')\nax.axvline(\'2021-03-15\', color="red", linestyle="--",  label=\'Fase Emergencial\')\nax.axvline(\'2021-08-17\', color="green", linestyle="--",  label=\'Fase Verde\')\nax.axvline(\'2021-11-01\', color="m", linestyle="--",  label=\'Fim das restrições\')\n'

# %%
break_dates = {'2020-03-24': "Label1",
               '2020-07-01': "Label2", 
               '2020-10-01': "Label3",
               '2021-04-01': "Label4",
               '2021-11-01': "Label5",
               '2022-01-15': "Label6"}

# %%
len(break_dates)
# Out:
# 6

# %%
list(break_dates.keys())
# Out:
# ['2020-03-24',
#  '2020-07-01',
#  '2020-10-01',
#  '2021-04-01',
#  '2021-11-01',
#  '2022-01-15']

# %%
cwc.trips_and_covid['2020-03': ]
# Out:
#             number_of_trips  tripduration  start_station_id  end_station_id  \
# date
# 2020-03-01           4198.0   1950.057184        139.747261      138.629497
# 2020-03-02           8960.0   1289.490397        104.507366      104.909030
# 2020-03-03          11866.0   1269.076631        105.329092      110.313248
# 2020-03-04          12823.0   1302.344099        111.610778      115.780161
# 2020-03-05          13096.0   1300.336771        108.595067      113.830406
# ...                     ...           ...               ...             ...
# 2022-04-26           7014.0   2498.257995        145.471913      148.455350
# 2022-04-27           7322.0   2514.078922        142.672767      145.502118
# 2022-04-28           7192.0   2661.764657        147.507786      149.033394
# 2022-04-29           5707.0   3163.509735        144.782898      143.025947
# 2022-04-30           3917.0   3771.788707        148.525147      152.096502
#
#                   age       hour  week_day weekend holiday  lat_start  \
# date
# 2020-03-01  29.480106  14.750119       6.0    True   False -23.581195
# 2020-03-02  30.148326  12.792746       0.0   False   False -23.580377
# 2020-03-03  30.055635  14.164335       1.0   False   False -23.580953
# 2020-03-04  30.062960  14.146612       2.0   False   False -23.580375
# 2020-03-05  30.116422  14.299786       3.0   False   False -23.580357
# ...               ...        ...       ...     ...     ...        ...
# 2022-04-26  31.908143  13.606929       1.0   False   False -23.575598
# 2022-04-27  31.709845  13.571019       2.0   False   False -23.576075
# 2022-04-28  31.698189  13.484705       3.0   False   False -23.575577
# 2022-04-29  31.182616  13.171894       4.0   False   False -23.575029
# 2022-04-30  31.613811  13.952770       5.0    True   False -23.573251
#
#             lon_start    lat_end    lon_end  distance  new_cases_ma  \
# date
# 2020-03-01 -46.673201 -23.581308 -46.673413  1.890444           NaN
# 2020-03-02 -46.678812 -23.582155 -46.678984  2.251742           NaN
# 2020-03-03 -46.678824 -23.581735 -46.679169  2.253035           NaN
# 2020-03-04 -46.677801 -23.581556 -46.678122  2.297365           NaN
# 2020-03-05 -46.679231 -23.581139 -46.679350  2.255893           NaN
# ...               ...        ...        ...       ...           ...
# 2022-04-26 -46.678925 -23.575609 -46.679454  2.433725       14692.0
# 2022-04-27 -46.678986 -23.576343 -46.679400  2.404509       12434.0
# 2022-04-28 -46.678949 -23.575886 -46.679469  2.390593       12613.0
# 2022-04-29 -46.679211 -23.575441 -46.679765  2.308745       13478.0
# 2022-04-30 -46.673087 -23.573418 -46.673434  2.121761       14633.0
#
#             new_deaths_ma
# date
# 2020-03-01            NaN
# 2020-03-02            NaN
# 2020-03-03            NaN
# 2020-03-04            NaN
# 2020-03-05            NaN
# ...                   ...
# 2022-04-26          102.0
# 2022-04-27           99.0
# 2022-04-28          102.0
# 2022-04-29          121.0
# 2022-04-30          126.0
#
# [791 rows x 16 columns]

# %%
'''
ax.axvline('2020-03-24', color="black", linestyle="--",  label=)
ax.axvline('2020-05-27', color="purple", linestyle="--",  label='Plano SP de retomada consciente')
ax.axvline('2020-10-06', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2020-11-30', color="yellow", linestyle="--",  label='Fase Amarela')
ax.axvline('2021-03-15', color="red", linestyle="--",  label='Fase Emergencial')
ax.axvline('2021-08-17', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2021-11-01', color="m", linestyle="--",  label='Fim das restrições')
'''

trips = cwc.trips_and_covid['2020':]
variable = 'number_of_trips'
break_dates = {'2020-03-24': '',
               '2020-07-01': '', 
               '2020-10-01': '',
               '2021-04-01': '',
               '2021-11-01': '',
               '2022-01-15': ''}



coeffs = bf.find_best_plot_fit(trips, variable, break_dates = break_dates,
                                poly_degree = 1, save = False)

# %%
'''
ax.axvline('2020-03-24', color="black", linestyle="--",  label=)
ax.axvline('2020-05-27', color="purple", linestyle="--",  label='Plano SP de retomada consciente')
ax.axvline('2020-10-06', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2020-11-30', color="yellow", linestyle="--",  label='Fase Amarela')
ax.axvline('2021-03-15', color="red", linestyle="--",  label='Fase Emergencial')
ax.axvline('2021-08-17', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2021-11-01', color="m", linestyle="--",  label='Fim das restrições')
'''

trips = cwc.trips_and_covid['2020':]
variable = 'number_of_trips'
break_dates = {'2020-03-24': 'Início do lockdown em SP',
               '2020-07-01': 'Fase Verde', 
               '2020-10-01': 'Fase Amarela',
               '2021-04-01': 'Fase Emergencial',
               '2021-11-01': "Fase Verde",
               '2022-01-15': 'Fim das restrições'}
break_dates = {'2020-03-24': 'Início do lockdown em SP',
               '2020-05-27': 'Plano SP de retomada consciente', 
               '2020-10-06': 'Fase Verde', 
               '2020-11-30': 'Fase Amarela',
               '2021-03-15': 'Fase Emergencial',
               '2021-08-17': "Fase Verde",
               '2021-11-01': 'Fim das restrições',
               '2022-01-15': 'Quebra identificada'}



coeffs = bf.find_best_plot_fit(trips, variable, break_dates = break_dates,
                                poly_degree = 1, save = False)

# %%
'''
ax.axvline('2020-03-24', color="black", linestyle="--",  label=)
ax.axvline('2020-05-27', color="purple", linestyle="--",  label='Plano SP de retomada consciente')
ax.axvline('2020-10-06', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2020-11-30', color="yellow", linestyle="--",  label='Fase Amarela')
ax.axvline('2021-03-15', color="red", linestyle="--",  label='Fase Emergencial')
ax.axvline('2021-08-17', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2021-11-01', color="m", linestyle="--",  label='Fim das restrições')
'''

trips = cwc.trips_and_covid['2020':]
variable = 'number_of_trips'
break_dates = {'2020-03-24': 'Início do lockdown em SP',
               '2020-07-01': 'Fase Verde', 
               '2020-10-01': 'Fase Amarela',
               '2021-04-01': 'Fase Emergencial',
               '2021-11-01': "Fase Verde",
               '2022-01-15': 'Fim das restrições'}
break_dates = {'2020-03-24': 'Início do lockdown em SP',
               '2020-05-27': 'Plano SP de retomada consciente', 
               '2020-10-06': 'Fase Verde', 
               '2020-11-30': 'Fase Amarela',
               '2021-03-15': 'Fase Emergencial',
               '2021-08-17': "Fase Verde",
               '2021-11-01': 'Fim das restrições'}



coeffs = bf.find_best_plot_fit(trips, variable, break_dates = break_dates,
                                poly_degree = 1, save = False)

# %%
'''
ax.axvline('2020-03-24', color="black", linestyle="--",  label=)
ax.axvline('2020-05-27', color="purple", linestyle="--",  label='Plano SP de retomada consciente')
ax.axvline('2020-10-06', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2020-11-30', color="yellow", linestyle="--",  label='Fase Amarela')
ax.axvline('2021-03-15', color="red", linestyle="--",  label='Fase Emergencial')
ax.axvline('2021-08-17', color="green", linestyle="--",  label='Fase Verde')
ax.axvline('2021-11-01', color="m", linestyle="--",  label='Fim das restrições')
'''

trips = cwc.trips_and_covid['2020-01':]
variable = 'number_of_trips'
# break_dates = {'2020-03-24': 'Início do lockdown em SP',
#                '2020-07-01': 'Fase Verde', 
#                '2020-10-01': 'Fase Amarela',
#                '2021-04-01': 'Fase Emergencial',
#                '2021-11-01': "Fase Verde",
#                '2022-01-15': 'Fim das restrições'}
break_dates = {'2020-03-06': 'Primeiro caso de COVID',
            #    '2020-03-24': 'Início do lockdown em SP',
               '2020-04-01': 'Início do lockdown em SP',
               '2020-05-27': 'Plano SP de retomada consciente', 
               '2020-10-06': 'Fase Verde', 
               '2020-11-30': 'Fase Amarela',
               '2021-01-04': 'Fase Amarela',
               # '2021-02-06': 'Fase Vermelha',
               # '2021-03-01': 'Fase Laranja',
               # '2021-03-06': 'Fase Vermelha',
               # '2021-03-15': 'Fase Emergencial',
               # '2021-04-12': 'Fase Vermelha',
               '2021-08-17': "Fase Verde",
               '2021-11-01': 'Fim das restrições',
               '2022-01-10': 'Festas de final de ano'
               }



coeffs = bf.find_best_plot_fit(trips, variable, break_dates = break_dates,
                                poly_degree = 1, save = True)

# %%
trips['2020-03-24':].index
# Out:
# DatetimeIndex(['2020-03-24', '2020-03-25', '2020-03-26', '2020-03-27',
#                '2020-03-28', '2020-03-29', '2020-03-30', '2020-03-31',
#                '2020-04-01', '2020-04-02',
#                ...
#                '2022-04-21', '2022-04-22', '2022-04-23', '2022-04-24',
#                '2022-04-25', '2022-04-26', '2022-04-27', '2022-04-28',
#                '2022-04-29', '2022-04-30'],
#               dtype='datetime64[ns]', name='date', length=768, freq=None)

# %%
coeffs
# Out:
# [array([ -399.14461538, 38764.93846154]),
#  array([ -15.10919344, 7330.67156528]),
#  array([  20.44833893, 1587.11434207]),
#  array([  -43.81969697, 19345.59090909]),
#  array([  -73.92128852, 30067.34369748]),
#  array([2.54331332e+00, 3.28025741e+03]),
#  array([  -19.98349966, 17864.11950786]),
#  array([  -47.95202519, 38497.25889249]),
#  array([   14.32881713, -6009.54475254])]
