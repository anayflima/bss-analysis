# %% [markdown]
# # Correlation between BSS trips and COVID-19

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import and prepare covid data

# %%
data_folder = '../data/'
covid_data = pd.read_csv(data_folder + 'covid/treated_data/data.csv')
covid_data
# Out:
#            date  new_cases_ma  new_deaths_ma
# 0    2020-03-06           2.0            NaN
# 1    2020-03-07           2.0            NaN
# 2    2020-03-08           3.0            NaN
# 3    2020-03-09           3.0            NaN
# 4    2020-03-10           4.0            NaN
# ..          ...           ...            ...
# 889  2022-08-12       21952.0          214.0
# 890  2022-08-13       19565.0          188.0
# 891  2022-08-14       18537.0          180.0
# 892  2022-08-15       20351.0          199.0
# 893  2022-08-16       19326.0          176.0
#
# [894 rows x 3 columns]

# %%
from modules.DataPreparation import DataPreparation
dp = DataPreparation()

# %%
covid_data = dp.transform_to_datetime(covid_data, ['date'])
covid_data = dp.transform_to_time_series(covid_data, 'date', drop=True)
covid_data
# Out:
#             new_cases_ma  new_deaths_ma
# date
# 2020-03-06           2.0            NaN
# 2020-03-07           2.0            NaN
# 2020-03-08           3.0            NaN
# 2020-03-09           3.0            NaN
# 2020-03-10           4.0            NaN
# ...                  ...            ...
# 2022-08-12       21952.0          214.0
# 2022-08-13       19565.0          188.0
# 2022-08-14       18537.0          180.0
# 2022-08-15       20351.0          199.0
# 2022-08-16       19326.0          176.0
#
# [894 rows x 2 columns]

# %% [markdown]
# ## Prepare trips data

# %%
data_folder = '../data/'
trips = pd.read_csv(data_folder + 'trips/analysis/trips_grouped_by_day.csv')
trips
# Out:
#             date  number_of_trips  tripduration       hour        age  \
# 0     2018-01-26                1    114.000000  15.000000        NaN
# 1     2018-01-27                8   2263.250000  14.250000        NaN
# 2     2018-01-28               12   7208.666667  14.833333        NaN
# 3     2018-01-29                8   5821.875000  15.500000        NaN
# 4     2018-01-30               69   3208.202899  16.144928        NaN
# ...          ...              ...           ...        ...        ...
# 1551  2022-04-26             7014   2645.781152  13.606929  31.908143
# 1552  2022-04-27             7322   2684.503688  13.571019  31.709845
# 1553  2022-04-28             7192   2778.109844  13.484705  31.698189
# 1554  2022-04-29             5707   3267.835290  13.171894  31.182616
# 1555  2022-04-30             3917   3817.494256  13.952770  31.613811
#
#       week_day  weekend  holiday
# 0          4.0      0.0      0.0
# 1          5.0      1.0      0.0
# 2          6.0      1.0      0.0
# 3          0.0      0.0      0.0
# 4          1.0      0.0      0.0
# ...        ...      ...      ...
# 1551       1.0      0.0      0.0
# 1552       2.0      0.0      0.0
# 1553       3.0      0.0      0.0
# 1554       4.0      0.0      0.0
# 1555       5.0      1.0      0.0
#
# [1556 rows x 8 columns]

# %%
from modules.DataPreparation import DataPreparation
dp = DataPreparation()

# %%
trips = dp.transform_to_datetime(trips, ['date'])

# %%
trips = dp.transform_to_time_series(trips, 'date', drop = True)

# %%
trips
# Out:
#             number_of_trips  tripduration       hour        age  week_day  \
# date
# 2018-01-26                1    114.000000  15.000000        NaN       4.0
# 2018-01-27                8   2263.250000  14.250000        NaN       5.0
# 2018-01-28               12   7208.666667  14.833333        NaN       6.0
# 2018-01-29                8   5821.875000  15.500000        NaN       0.0
# 2018-01-30               69   3208.202899  16.144928        NaN       1.0
# ...                     ...           ...        ...        ...       ...
# 2022-04-26             7014   2645.781152  13.606929  31.908143       1.0
# 2022-04-27             7322   2684.503688  13.571019  31.709845       2.0
# 2022-04-28             7192   2778.109844  13.484705  31.698189       3.0
# 2022-04-29             5707   3267.835290  13.171894  31.182616       4.0
# 2022-04-30             3917   3817.494256  13.952770  31.613811       5.0
#
#             weekend  holiday
# date
# 2018-01-26      0.0      0.0
# 2018-01-27      1.0      0.0
# 2018-01-28      1.0      0.0
# 2018-01-29      0.0      0.0
# 2018-01-30      0.0      0.0
# ...             ...      ...
# 2022-04-26      0.0      0.0
# 2022-04-27      0.0      0.0
# 2022-04-28      0.0      0.0
# 2022-04-29      0.0      0.0
# 2022-04-30      1.0      0.0
#
# [1556 rows x 7 columns]

# %% [markdown]
# ## Merge COVID and trip data

# %%
trips_and_covid = pd.merge(trips, covid_data, left_index=True, right_index=True, how = 'left')
trips_and_covid
# Out:
#             number_of_trips  tripduration       hour        age  week_day  \
# date
# 2018-01-26                1    114.000000  15.000000        NaN       4.0
# 2018-01-27                8   2263.250000  14.250000        NaN       5.0
# 2018-01-28               12   7208.666667  14.833333        NaN       6.0
# 2018-01-29                8   5821.875000  15.500000        NaN       0.0
# 2018-01-30               69   3208.202899  16.144928        NaN       1.0
# ...                     ...           ...        ...        ...       ...
# 2022-04-26             7014   2645.781152  13.606929  31.908143       1.0
# 2022-04-27             7322   2684.503688  13.571019  31.709845       2.0
# 2022-04-28             7192   2778.109844  13.484705  31.698189       3.0
# 2022-04-29             5707   3267.835290  13.171894  31.182616       4.0
# 2022-04-30             3917   3817.494256  13.952770  31.613811       5.0
#
#             weekend  holiday  new_cases_ma  new_deaths_ma
# date
# 2018-01-26      0.0      0.0           NaN            NaN
# 2018-01-27      1.0      0.0           NaN            NaN
# 2018-01-28      1.0      0.0           NaN            NaN
# 2018-01-29      0.0      0.0           NaN            NaN
# 2018-01-30      0.0      0.0           NaN            NaN
# ...             ...      ...           ...            ...
# 2022-04-26      0.0      0.0       14692.0          102.0
# 2022-04-27      0.0      0.0       12434.0           99.0
# 2022-04-28      0.0      0.0       12613.0          102.0
# 2022-04-29      0.0      0.0       13478.0          121.0
# 2022-04-30      1.0      0.0       14633.0          126.0
#
# [1556 rows x 9 columns]

# %%
trips_and_covid['age'].first_valid_index()
# Out:
# Timestamp('2020-01-01 00:00:00')

# %% [markdown]
# ## Correlation

# %%
def plot_all_correlations(data):
    # get the data correlation matrix
    corr = data.corr()
    plt.figure(figsize=(9, 7))
    plt.imshow(corr.abs(), cmap='Blues', interpolation='none', aspect='auto')
    plt.colorbar()
    plt.xticks(range(len(corr)), corr.columns, rotation='vertical')
    plt.yticks(range(len(corr)), corr.columns)
    plt.suptitle('Absolute Correlation between variables', fontsize=15, fontweight='bold')
    plt.grid(False)
    plt.show()
    return corr

def plot_target_variable_correlation(data, corr, target_variable):
    correlation = np.array(corr[target_variable])
    # remove correlation with itself
    correlation = np.delete(correlation, np.where(correlation == 1))
    columns = np.array(data.keys())
    columns =  np.delete(columns, np.where(columns == target_variable))
    plt.figure(figsize=(15, 7))
    plt.bar(columns, abs(correlation))
    plt.title("Correlation with '{variable}' variable".format(variable = target_variable))
    plt.show(True)

# %%
correlation_matrix = plot_all_correlations(trips_and_covid)

# %% [markdown]
# ## COVID-19 cases

# %%
correlation_with_variable = plot_target_variable_correlation(trips_and_covid,
                                                             correlation_matrix, 'new_cases_ma')
correlation_with_variable

# %% [markdown]
# ## COVID-19 deaths

# %%
correlation_with_variable = plot_target_variable_correlation(trips_and_covid,
                                                                correlation_matrix, 'new_deaths_ma')
correlation_with_variable

# %% [markdown]
# ### Plot together

# %%
def plot_variable_and_covid_together(variable, covid_variable):
    trips_and_covid_plot = trips_and_covid.filter([variable, covid_variable])
    trips_and_covid_plot.plot(secondary_y = covid_variable)

# %%
variable = 'number_of_trips'
covid_variable = 'new_cases_ma'
plot_variable_and_covid_together(variable, covid_variable)

# %%
variable = 'tripduration'
covid_variable = 'new_cases_ma'
plot_variable_and_covid_together(variable, covid_variable)

# %%
variable = 'age'
covid_variable = 'new_cases_ma'
plot_variable_and_covid_together(variable, covid_variable)
